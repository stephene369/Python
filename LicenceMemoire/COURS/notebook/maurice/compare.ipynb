# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
aple = yf.download("AAPL" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
micro = yf.download("MSFT" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
goog = yf.download("GOOG" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
amaz = yf.download("AMZN" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nvid = yf.download("NVDA" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
brk = yf.download("BRK.A" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRK.A: No timezone found, symbol may be delisted

# %%
meta = yf.download("META" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesl = yf.download("TSLA" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
v = yf.download("V" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
unh = yf.download("UNH" ,"2005-11-24","2023-05-10" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fig = plt.figure(figsize=(12,6),dpi=300)

fig.add_axes([0,0,1,1])
aple['Close'].plot(label='Apple')
micro['Close'].plot(label="Microsoft")
#unh['Close'].plot(label="UnitedHealth")
#v['Close'].plot(label="VISA")
#tesl['Close'].plot(label="TESLA")
#meta['Close'].plot(label="META")
nvid['Close'].plot(label="NVIDIA")
amaz['Close'].plot(label="Amazon")
#goog['Close'].plot(label="Google")

plt.legend() ;
# Out:
# ''
